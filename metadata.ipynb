# %% [markdown]
# #### Importamos dependencias

# %%
from requests.auth import HTTPBasicAuth
from impala.dbapi import connect
from datetime import datetime
from pyhive import hive
import pandas as pd
import requests
import sqlparse
import json
import sys
import os
import re
# Out:
# /tmp/ipykernel_17260/4139856990.py:5: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
with open('data/data.json') as f:
    file = f.read()
    json_file = json.loads(file)

# %%
print(json.dumps(json_file, indent=2))
# Out:
# {
#   "de_ber_4con.productos_parametria_dim_productos": {
#     "database": "de_ber_4con",
#     "table_name": "productos_parametria_dim_productos",
#     "create_table": "",
#     "associated_term": "productos_parametria_dim_productos_unisys",
#     "loading_query": "SELECT id_concepto AS id_concepto, cod_producto AS cod_producto, id_moneda AS id_moneda, fecha_proceso AS fecha_proceso, id_producto AS id_producto, marca_sfb AS marca_sfb, marca_producto_cta_comitente AS marca_producto_cta_comitente, cast(fecha_vencimiento_producto as varchar(10)) AS fecha_vencimiento_producto, cast(fecha_vigencia_producto as varchar(10)) AS fecha_vigencia_producto, desc_producto AS desc_producto, nro_campo_c_467 AS nro_campo_c_467, nro_campo_garantia AS nro_campo_garantia, nro_campo_lisol AS nro_campo_lisol, factor_ponderacion AS factor_ponderacion, fecha_vencimiento_producto_rel AS fecha_vencimiento_producto_rel, fecha_vigencia_producto_rel AS fecha_vigencia_producto_rel, estado AS estado, marca_producto_privado AS marca_producto_privado FROM de_ber_3ref.productos_parametria_dim_productos WHERE fecha_proceso='$FECHA_PROCESO'",
#     "affected_tables": [
#       "de_ber_datamart_control_gestion.productos_prestamos_dim_maestro"
#     ]
#   },
#   "de_bsc_4con.productos_parametria_dim_productos": {
#     "database": "de_bsc_4con",
#     "table_name": "productos_parametria_dim_productos",
#     "create_table": "",
#     "associated_term": "productos_parametria_dim_productos_unisys",
#     "loading_query": "SELECT id_concepto AS id_concepto, cod_producto AS cod_producto, id_moneda AS id_moneda, fecha_proceso AS fecha_proceso, id_producto AS id_producto, marca_sfb AS marca_sfb, marca_producto_cta_comitente AS marca_producto_cta_comitente, cast(fecha_vencimiento_producto as varchar(10)) AS fecha_vencimiento_producto, cast(fecha_vigencia_producto as varchar(10)) AS fecha_vigencia_producto, desc_producto AS desc_producto, nro_campo_c_467 AS nro_campo_c_467, nro_campo_garantia AS nro_campo_garantia, nro_campo_lisol AS nro_campo_lisol, factor_ponderacion AS factor_ponderacion, fecha_vencimiento_producto_rel AS fecha_vencimiento_producto_rel, fecha_vigencia_producto_rel AS fecha_vigencia_producto_rel, estado AS estado, marca_producto_privado AS marca_producto_privado FROM de_bsc_3ref.productos_parametria_dim_productos WHERE fecha_proceso='$FECHA_PROCESO'",
#     "affected_tables": [
#       "de_bsc_datamart_control_gestion.productos_prestamos_dim_maestro"
#     ]
#   },
#   "de_bsj_4con.productos_parametria_dim_productos": {
#     "database": "de_bsj_4con",
#     "table_name": "productos_parametria_dim_productos",
#     "create_table": "",
#     "associated_term": "productos_parametria_dim_productos_unisys",
#     "loading_query": "SELECT id_concepto AS id_concepto, cod_producto AS cod_producto, id_moneda AS id_moneda, fecha_proceso AS fecha_proceso, id_producto AS id_producto, marca_sfb AS marca_sfb, marca_producto_cta_comitente AS marca_producto_cta_comitente, cast(fecha_vencimiento_producto as varchar(10)) AS fecha_vencimiento_producto, cast(fecha_vigencia_producto as varchar(10)) AS fecha_vigencia_producto, desc_producto AS desc_producto, nro_campo_c_467 AS nro_campo_c_467, nro_campo_garantia AS nro_campo_garantia, nro_campo_lisol AS nro_campo_lisol, factor_ponderacion AS factor_ponderacion, fecha_vencimiento_producto_rel AS fecha_vencimiento_producto_rel, fecha_vigencia_producto_rel AS fecha_vigencia_producto_rel, estado AS estado, marca_producto_privado AS marca_producto_privado FROM de_bsj_3ref.productos_parametria_dim_productos WHERE fecha_proceso='$FECHA_PROCESO'",
#     "affected_tables": [
#       "de_bsj_datamart_control_gestion.productos_prestamos_dim_maestro"
#     ]
#   },
#   "de_ber_3ref.productos_parametria_dim_productos": {
#     "database": "de_ber_3ref",
#     "table_name": "productos_parametria_dim_productos",
#     "create_table": "",
#     "associated_term": "productos_parametria_dim_productos_unisys",
#     "loading_query": "SELECT COD_CONCE AS id_concepto,        COD_PROD AS cod_producto,        ID_PROD AS id_producto,        SENAL_SFB AS marca_sfb,        PROD_COMIT AS marca_producto_cta_comitente,        COD_MONEDA AS id_moneda,        FEC_VTO_PROD AS fecha_vencimiento_producto,        FEC_VIG_PRO AS fecha_vigencia_producto,        NOM_PROD AS desc_producto,        CAMPO_C_467 AS nro_campo_c_467,        CAMPO_GTIA AS nro_campo_garantia,        CAMPO_LISOL AS nro_campo_lisol,        FACT_POND AS factor_ponderacion,        FEC_VTO_PRO AS fecha_vencimiento_producto_rel,        FEC_VIG_PROD AS fecha_vigencia_producto_rel,        ESTADO AS estado,        PROD_PRIVA AS marca_producto_privado FROM de_ber_2cur.productos_aampr WHERE fecha_proceso='$FECHA_PROCESO'",
#     "affected_tables": [
#       "de_ber_4con.productos_parametria_dim_productos"
#     ]
#   },
#   "de_bsc_3ref.productos_parametria_dim_productos": {
#     "database": "de_bsc_3ref",
#     "table_name": "productos_parametria_dim_productos",
#     "create_table": "",
#     "associated_term": "productos_parametria_dim_productos_unisys",
#     "loading_query": "SELECT COD_CONCE AS id_concepto,        COD_PROD AS cod_producto,        ID_PROD AS id_producto,        SENAL_SFB AS marca_sfb,        PROD_COMIT AS marca_producto_cta_comitente,        COD_MONEDA AS id_moneda,        FEC_VTO_PROD AS fecha_vencimiento_producto,        FEC_VIG_PRO AS fecha_vigencia_producto,        NOM_PROD AS desc_producto,        CAMPO_C_467 AS nro_campo_c_467,        CAMPO_GTIA AS nro_campo_garantia,        CAMPO_LISOL AS nro_campo_lisol,        FACT_POND AS factor_ponderacion,        FEC_VTO_PRO AS fecha_vencimiento_producto_rel,        FEC_VIG_PROD AS fecha_vigencia_producto_rel,        ESTADO AS estado,        PROD_PRIVA AS marca_producto_privado FROM de_bsc_2cur.productos_aampr WHERE fecha_proceso='$FECHA_PROCESO'",
#     "affected_tables": [
#       "de_bsc_4con.productos_parametria_dim_productos"
#     ]
#   },
#   "de_bsj_3ref.productos_parametria_dim_productos": {
#     "database": "de_bsj_3ref",
#     "table_name": "productos_parametria_dim_productos",
#     "create_table": "",
#     "associated_term": "productos_parametria_dim_productos_unisys",
#     "loading_query": "SELECT COD_CONCE AS id_concepto,        COD_PROD AS cod_producto,        ID_PROD AS id_producto,        SENAL_SFB AS marca_sfb,        PROD_COMIT AS marca_producto_cta_comitente,        COD_MONEDA AS id_moneda,        FEC_VTO_PROD AS fecha_vencimiento_producto,        FEC_VIG_PRO AS fecha_vigencia_producto,        NOM_PROD AS desc_producto,        CAMPO_C_467 AS nro_campo_c_467,        CAMPO_GTIA AS nro_campo_garantia,        CAMPO_LISOL AS nro_campo_lisol,        FACT_POND AS factor_ponderacion,        FEC_VTO_PRO AS fecha_vencimiento_producto_rel,        FEC_VIG_PROD AS fecha_vigencia_producto_rel,        ESTADO AS estado,        PROD_PRIVA AS marca_producto_privado FROM de_bsj_2cur.productos_aampr WHERE fecha_proceso='$FECHA_PROCESO'",
#     "affected_tables": [
#       "de_bsj_4con.productos_parametria_dim_productos"
#     ]
#   },
#   "de_ber_2cur.productos_aampr": {
#     "database": "de_ber_2cur",
#     "table_name": "productos_aampr",
#     "create_table": "",
#     "associated_term": "aampr",
#     "loading_query": "SELECT cast(glb_dtime AS bigint) AS glb_dtime,        cast(aco_conce AS int) AS cod_conce,        cast(aco_produ AS int) AS cod_prod,        acoidprod AS id_prod,        cast(ase_essfb AS varchar(1)) AS senal_sfb,        cast(aseprocom AS varchar(1)) AS prod_comit,        cast(dco_moned AS int)AS cod_moneda,        to_date( from_unixtime( unix_timestamp( cast( from_unixtime( unix_timestamp( SUBSTR( CONCAT('000', afevenpro), -6 ), 'ddMMyy' ), 'yyyyMMdd' ) AS varchar(8) ), 'yyyyMMdd' ), 'yyyy-MM-dd' ) ) AS fec_vto_prod,        to_date( from_unixtime( unix_timestamp( cast( from_unixtime( unix_timestamp( SUBSTR( CONCAT('000', afevigpro), -6 ), 'ddMMyy' ), 'yyyyMMdd' ) AS varchar(8) ), 'yyyyMMdd' ), 'yyyy-MM-dd' ) ) AS fec_vig_pro,        cast(ano_produ AS char(30)) AS nom_prod,        cast(anu_ca467 AS varchar(2)) AS campo_c_467,        cast(anu_campo AS varchar(2))campo_gtia,        cast(anu_lisol AS varchar(2)) AS campo_lisol,        cast(apofacpon AS decimal(8,4)) AS fact_pond,        cast(arevenpro AS varchar(5)) AS fec_vto_pro,        cast(arevigpro AS varchar(5)) AS fec_vig_prod,        estado AS estado,        cast(ase_priva AS varchar(1)) AS prod_priva FROM de_ber_1raw.sfb_aampr WHERE fecha_proceso='$FECHA_PROCESO'",
#     "affected_tables": [
#       "de_ber_3ref.productos_parametria_dim_productos",
#       "de_ber_3ref.productos_cta_corriente_dim_maestro",
#       "de_ber_3ref.productos_garantias_dim_maestro"
#     ]
#   },
#   "de_bsc_2cur.productos_aampr": {
#     "database": "de_bsc_2cur",
#     "table_name": "productos_aampr",
#     "create_table": "",
#     "associated_term": "aampr",
#     "loading_query": "SELECT cast(glb_dtime AS bigint) AS glb_dtime,        cast(aco_conce AS int) AS cod_conce,        cast(aco_produ AS int) AS cod_prod,        acoidprod AS id_prod,        cast(ase_essfb AS varchar(1)) AS senal_sfb,        cast(aseprocom AS varchar(1)) AS prod_comit,        cast(dco_moned AS int)AS cod_moneda,        to_date( from_unixtime( unix_timestamp( cast( from_unixtime( unix_timestamp( SUBSTR( CONCAT('000', afevenpro), -6 ), 'ddMMyy' ), 'yyyyMMdd' ) AS varchar(8) ), 'yyyyMMdd' ), 'yyyy-MM-dd' ) ) AS fec_vto_prod,        to_date( from_unixtime( unix_timestamp( cast( from_unixtime( unix_timestamp( SUBSTR( CONCAT('000', afevigpro), -6 ), 'ddMMyy' ), 'yyyyMMdd' ) AS varchar(8) ), 'yyyyMMdd' ), 'yyyy-MM-dd' ) ) AS fec_vig_pro,        cast(ano_produ AS char(30)) AS nom_prod,        cast(anu_ca467 AS varchar(2)) AS campo_c_467,        cast(anu_campo AS varchar(2))campo_gtia,        cast(anu_lisol AS varchar(2)) AS campo_lisol,        cast(apofacpon AS decimal(8,4)) AS fact_pond,        cast(arevenpro AS varchar(5)) AS fec_vto_pro,        cast(arevigpro AS varchar(5)) AS fec_vig_prod,        estado AS estado,        cast(ase_priva AS varchar(1)) AS prod_priva FROM de_bsc_1raw.sfb_aampr WHERE fecha_proceso='$FECHA_PROCESO'",
#     "affected_tables": [
#       "de_bsc_3ref.productos_parametria_dim_productos",
#       "de_bsc_3ref.productos_cta_corriente_dim_maestro",
#       "de_bsc_3ref.productos_garantias_dim_maestro"
#     ]
#   },
#   "de_bsj_2cur.productos_aampr": {
#     "database": "de_bsj_2cur",
#     "table_name": "productos_aampr",
#     "create_table": "",
#     "associated_term": "aampr",
#     "loading_query": "SELECT cast(glb_dtime AS bigint) AS glb_dtime,        cast(aco_conce AS int) AS cod_conce,        cast(aco_produ AS int) AS cod_prod,        acoidprod AS id_prod,        cast(ase_essfb AS varchar(1)) AS senal_sfb,        cast(aseprocom AS varchar(1)) AS prod_comit,        cast(dco_moned AS int)AS cod_moneda,        to_date( from_unixtime( unix_timestamp( cast( from_unixtime( unix_timestamp( SUBSTR( CONCAT('000', afevenpro), -6 ), 'ddMMyy' ), 'yyyyMMdd' ) AS varchar(8) ), 'yyyyMMdd' ), 'yyyy-MM-dd' ) ) AS fec_vto_prod,        to_date( from_unixtime( unix_timestamp( cast( from_unixtime( unix_timestamp( SUBSTR( CONCAT('000', afevigpro), -6 ), 'ddMMyy' ), 'yyyyMMdd' ) AS varchar(8) ), 'yyyyMMdd' ), 'yyyy-MM-dd' ) ) AS fec_vig_pro,        cast(ano_produ AS char(30)) AS nom_prod,        cast(anu_ca467 AS varchar(2)) AS campo_c_467,        cast(anu_campo AS varchar(2))campo_gtia,        cast(anu_lisol AS varchar(2)) AS campo_lisol,        cast(apofacpon AS decimal(8,4)) AS fact_pond,        cast(arevenpro AS varchar(5)) AS fec_vto_pro,        cast(arevigpro AS varchar(5)) AS fec_vig_prod,        estado AS estado,        cast(ase_priva AS varchar(1)) AS prod_priva FROM de_bsj_1raw.sfb_aampr WHERE fecha_proceso='$FECHA_PROCESO'",
#     "affected_tables": [
#       "de_bsj_3ref.productos_parametria_dim_productos",
#       "de_bsj_3ref.productos_cta_corriente_dim_maestro",
#       "de_bsj_3ref.productos_garantias_dim_maestro"
#     ]
#   },
#   "de_ber_3ref.productos_prestamos_dim_maestro": {
#     "database": "de_ber_3ref",
#     "table_name": "productos_prestamos_dim_maestro",
#     "create_table": "",
#     "associated_term": "prest_productos_prestamos_dim_maestro_unisys",
#     "loading_query": "SELECT    pprpc.id_producto AS id_producto,    pprpc.id_moneda AS id_moneda_2,    ppmpr.id_moneda AS id_moneda_3,    ppaso.id_suc_cuenta AS id_suc_cuenta,    ppaso.id_num_cuenta AS id_num_cuenta,    ppmap.atributo_bcra AS id_sector,    ppmap.ejecutivo_cta AS ejecutivo_cta,    ppmap.marca_prestamo AS marca_prestamo,    ppmap.id_sistema_anterior AS id_sistema_anterior,    ppmap.id_moneda AS id_moneda,    ppmap.oficina AS id_sucursal,    ppmap.producto AS id_linea,    ppmap.nro_prestamo AS nro_operacion,    ppmap.nro_expediente_cfi_complemento AS nro_expediente_cfi_complemento,    ppmap.oficina_anterior_prestamo AS oficina_anterior_prestamo,    ppmap.nro_prestamo_viejo_1 AS nro_prestamo_viejo_1,    ppmap.nro_prestamo_viejo AS nro_prestamo_viejo,    ppmap.fecha_relativa_liquidacion AS fecha_de_liquidacion,    ppmap.id_cliente_core AS id_cliente_core,    ppmap.base_calculo AS base_calculo,    ppmap.debito_automatico AS debito_automatico,    ppmap.tratamiento_iva AS tratamiento_iva,    ppmap.oficina_debito_automatico AS oficina_debito_automatico,    ppmap.digito_verificador_debito_automatico AS digito_verificador_debito_automatico,    ppmap.nro_cta_deb_automatico AS nro_cta_deb_automatico,    ppmap.marca_en_uso AS marca_en_uso,    ppmap.mto_cotizacion_venta AS mto_cotizacion_venta,    ppmap.concepto_cta_acreditacion AS concepto_cta_acreditacion,    ppmap.sucursal_cta_acreditacion AS sucursal_cta_acreditacion,    ppmap.digito_verificador_cta_acreditacion AS digito_verificador_cta_acreditacion,    ppmap.nro_cta_acreditacion AS nro_cta_acreditacion,    ppmap.cant_cuotas AS cant_cuotas,    ppmap.cant_documentos AS cant_documentos,    ppmap.cant_clientes_mancomunados AS cant_clientes_mancomunados,    ppmap.dias_feriado_ultima_cuota AS dias_feriado_ultima_cuota,    ppmap.cant_cuotas_pagas AS cant_cuotas_pagas,    ppmap.cod_calificacion AS cod_calificacion,    ppmap.destino_fondos AS destino_fondos,    ppmap.id_formula AS id_formula,    ppmap.id_tasa_interes_punitorio AS id_tasa_interes_punitorio,    ppmap.id_tasa_interes_normal AS id_tasa_interes_normal,    ppmap.base_calculo_interes_punitorio AS base_calculo_interes_punitorio,    ppmap.base_calculo_interes_comp AS base_calculo_interes_comp,    ppmap.tipo_devengamiento AS tipo_devengamiento,    ppmap.id_cambio_situacion AS id_cambio_situacion,    ppmap.id_tasa_interes_vencido AS id_tasa_interes_vencido,    ppmap.id_forma_aplicacion_tasa AS id_forma_aplicacion_tasa,    ppmap.id_aplicacion_spread_tasa AS id_aplicacion_spread_tasa,    ppmap.id_sistema_amortizacion AS id_sistema_amortizacion,    ppmap.id_tratamiento_ley25063 AS id_tratamiento_ley25063,    ppmap.id_tratamiento_iva AS id_tratamiento_iva,    ppmap.dias_generar_cuota AS dias_generar_cuota,    ppmap.dias_gracia AS dias_gracia,    ppmap.dias_devengamiento_mes AS dias_devengamiento_mes,    ppmap.dias_periodo AS dias_periodo,    ppmap.dias_gracias_pago_cuotas AS dias_gracias_pago_cuotas,    ppmap.dias_gracias_restantes AS dias_gracias_restantes,    ppmap.dias_vto_cuotas AS dias_vto_cuotas,    ppmap.dias_reintento_debito_automatico AS dias_reintento_debito_automatico,    ppmap.dias_teoricos_periodo AS dias_teoricos_periodo,    ppmap.spread_de_tasa AS spread_de_tasa,    ppmap.fecha_cancelacion AS fecha_baja,    ppmap.fecha_ultimo_pago AS fecha_ultimo_pago,    ppmap.fecha_liquidacion AS fecha_alta,    ppmap.fecha_primer_vto AS fecha_primer_vto,    ppmap.fecha_vto_credito AS fecha_vto_credito,    ppmap.fecha_calculo_mora_fv AS fecha_calculo_mora_fv,    ppmap.fecha_cambio_estado AS fecha_cambio_estado,    ppmap.fecha_inicio_spread_tasa_vigente AS fecha_inicio_spread_tasa_vigente,    ppmap.fecha_inicio_tasa_vigente AS fecha_inicio_tasa_vigente,    ppmap.fecha_vto_proxima_factura AS fecha_vto_proxima_factura,    ppmap.fecha_ultimo_pago_cuota AS fecha_ultimo_pago_cuota,    ppmap.fecha_ultima_transaccion AS fecha_ultima_transaccion,    ppmap.fecha_vto_spread_tasa_vigente AS fecha_vto_spread_tasa_vigente,    ppmap.fecha_v ...
#     "affected_tables": [
#       "de_ber_4con.productos_prestamos_dim_maestro"
#     ]
#   },
#   "de_bsc_3ref.productos_prestamos_dim_maestro": {
#     "database": "de_bsc_3ref",
#     "table_name": "productos_prestamos_dim_maestro",
#     "create_table": "",
#     "associated_term": "prest_productos_prestamos_dim_maestro_unisys",
#     "loading_query": "SELECT    pprpc.id_producto AS id_producto,    pprpc.id_moneda AS id_moneda_2,    ppmpr.id_moneda AS id_moneda_3,    ppaso.id_suc_cuenta AS id_suc_cuenta,    ppaso.id_num_cuenta AS id_num_cuenta,    ppmap.atributo_bcra AS id_sector,    ppmap.ejecutivo_cta AS ejecutivo_cta,    ppmap.marca_prestamo AS marca_prestamo,    ppmap.id_sistema_anterior AS id_sistema_anterior,    ppmap.id_moneda AS id_moneda,    ppmap.oficina AS id_sucursal,    ppmap.producto AS id_linea,    ppmap.nro_prestamo AS nro_operacion,    ppmap.nro_expediente_cfi_complemento AS nro_expediente_cfi_complemento,    ppmap.oficina_anterior_prestamo AS oficina_anterior_prestamo,    ppmap.nro_prestamo_viejo_1 AS nro_prestamo_viejo_1,    ppmap.nro_prestamo_viejo AS nro_prestamo_viejo,    ppmap.fecha_relativa_liquidacion AS fecha_de_liquidacion,    ppmap.id_cliente_core AS id_cliente_core,    ppmap.base_calculo AS base_calculo,    ppmap.debito_automatico AS debito_automatico,    ppmap.tratamiento_iva AS tratamiento_iva,    ppmap.oficina_debito_automatico AS oficina_debito_automatico,    ppmap.digito_verificador_debito_automatico AS digito_verificador_debito_automatico,    ppmap.nro_cta_deb_automatico AS nro_cta_deb_automatico,    ppmap.marca_en_uso AS marca_en_uso,    ppmap.mto_cotizacion_venta AS mto_cotizacion_venta,    ppmap.concepto_cta_acreditacion AS concepto_cta_acreditacion,    ppmap.sucursal_cta_acreditacion AS sucursal_cta_acreditacion,    ppmap.digito_verificador_cta_acreditacion AS digito_verificador_cta_acreditacion,    ppmap.nro_cta_acreditacion AS nro_cta_acreditacion,    ppmap.cant_cuotas AS cant_cuotas,    ppmap.cant_documentos AS cant_documentos,    ppmap.cant_clientes_mancomunados AS cant_clientes_mancomunados,    ppmap.dias_feriado_ultima_cuota AS dias_feriado_ultima_cuota,    ppmap.cant_cuotas_pagas AS cant_cuotas_pagas,    ppmap.cod_calificacion AS cod_calificacion,    ppmap.destino_fondos AS destino_fondos,    ppmap.id_formula AS id_formula,    ppmap.id_tasa_interes_punitorio AS id_tasa_interes_punitorio,    ppmap.id_tasa_interes_normal AS id_tasa_interes_normal,    ppmap.base_calculo_interes_punitorio AS base_calculo_interes_punitorio,    ppmap.base_calculo_interes_comp AS base_calculo_interes_comp,    ppmap.tipo_devengamiento AS tipo_devengamiento,    ppmap.id_cambio_situacion AS id_cambio_situacion,    ppmap.id_tasa_interes_vencido AS id_tasa_interes_vencido,    ppmap.id_forma_aplicacion_tasa AS id_forma_aplicacion_tasa,    ppmap.id_aplicacion_spread_tasa AS id_aplicacion_spread_tasa,    ppmap.id_sistema_amortizacion AS id_sistema_amortizacion,    ppmap.id_tratamiento_ley25063 AS id_tratamiento_ley25063,    ppmap.id_tratamiento_iva AS id_tratamiento_iva,    ppmap.dias_generar_cuota AS dias_generar_cuota,    ppmap.dias_gracia AS dias_gracia,    ppmap.dias_devengamiento_mes AS dias_devengamiento_mes,    ppmap.dias_periodo AS dias_periodo,    ppmap.dias_gracias_pago_cuotas AS dias_gracias_pago_cuotas,    ppmap.dias_gracias_restantes AS dias_gracias_restantes,    ppmap.dias_vto_cuotas AS dias_vto_cuotas,    ppmap.dias_reintento_debito_automatico AS dias_reintento_debito_automatico,    ppmap.dias_teoricos_periodo AS dias_teoricos_periodo,    ppmap.spread_de_tasa AS spread_de_tasa,    ppmap.fecha_cancelacion AS fecha_baja,    ppmap.fecha_ultimo_pago AS fecha_ultimo_pago,    ppmap.fecha_liquidacion AS fecha_alta,    ppmap.fecha_primer_vto AS fecha_primer_vto,    ppmap.fecha_vto_credito AS fecha_vto_credito,    ppmap.fecha_calculo_mora_fv AS fecha_calculo_mora_fv,    ppmap.fecha_cambio_estado AS fecha_cambio_estado,    ppmap.fecha_inicio_spread_tasa_vigente AS fecha_inicio_spread_tasa_vigente,    ppmap.fecha_inicio_tasa_vigente AS fecha_inicio_tasa_vigente,    ppmap.fecha_vto_proxima_factura AS fecha_vto_proxima_factura,    ppmap.fecha_ultimo_pago_cuota AS fecha_ultimo_pago_cuota,    ppmap.fecha_ultima_transaccion AS fecha_ultima_transaccion,    ppmap.fecha_vto_spread_tasa_vigente AS fecha_vto_spread_tasa_vigente,    ppmap.fecha_v ...
#     "affected_tables": [
#       "de_bsc_4con.productos_prestamos_dim_maestro"
#     ]
#   },
#   "de_bsf_3ref.productos_prestamos_dim_maestro": {
#     "database": "de_bsf_3ref",
#     "table_name": "productos_prestamos_dim_maestro",
#     "create_table": "",
#     "associated_term": "prest_productos_prestamos_dim_maestro_bsf",
#     "loading_query": "SELECT         crmaeprbf.id_sucursal AS id_sucursal,        crmaeprbf.id_linea AS id_linea,        crmaeprbf.nro_operacion AS nro_operacion,        crpar01bf.id_linea AS id_linea,        crpar02bf.cod_tipo_linea AS cod_tipo_linea,        crprlinsol.id_sucursal AS id_sucursal,        crprlinsol.id_linea AS id_linea,        crprlinsol.id_cliente_core AS id_cliente_core,        crprlinsol.nro_transaccion AS nro_transaccion,        crprlinsol.pplnoper AS pplnoper,        craltacbf.id_sucursal AS id_sucursal,        craltacbf.id_linea AS id_linea,        craltacbf.nro_operacion AS nro_operacion,        crmaecfbf.id_sucursal AS id_sucursal,        crmaecfbf.id_linea AS id_linea,        crmaecfbf.nro_operacion AS nro_operacion,        crmaeprbf.id_sucursal_cta AS id_sucursal_cta,        crmaeprbf.id_tipo_cta AS id_tipo_cta,        crmaeprbf.nro_cta AS nro_cta,        crmaeprbf.id_cliente_core AS id_cliente_core,        crmaeprbf.mpnombre AS mpnombre,        crmaeprbf.mpuserapr AS mpuserapr,        crmaeprbf.mpfaprob AS mpfaprob,        crmaeprbf.mpplan AS mpplan,        crmaeprbf.mptipre AS mptipre,        crmaeprbf.mpfliq AS mpfliq,        crmaeprbf.mpfcanc AS mpfcanc,        crmaeprbf.mpfulpagcuo AS mpfulpagcuo,        crmaeprbf.mpfulamext AS mpfulamext,        crmaeprbf.mpcodfvtos AS mpcodfvtos,        crmaeprbf.mpcanint AS mpcanint,        crmaeprbf.mpcancap AS mpcancap,        crmaeprbf.mpplazo AS mpplazo,        crmaeprbf.mpvtofinal AS mpvtofinal,        crmaeprbf.mpperint AS mpperint,        crmaeprbf.mppercap AS mppercap,        crmaeprbf.mppergracap AS mppergracap,        crmaeprbf.mpttasa AS mpttasa,        crmaeprbf.mptasa AS mptasa,        crmaeprbf.mptasanom AS mptasanom,        crmaeprbf.mpinctipo AS mpinctipo,        crmaeprbf.mpinctasa AS mpinctasa,        crmaeprbf.mpfvto1 AS mpfvto1,        crmaeprbf.mpsalcapaju AS mpsalcapaju,        crmaeprbf.mpsalcapbase AS mpsalcapbase,        crmaeprbf.mpcapitalbase AS mpcapitalbase,        crmaeprbf.mpcapentregado AS mpcapentregado,        crmaeprbf.id_moneda AS id_moneda,        crmaeprbf.mpcotbase AS mpcotbase,        crmaeprbf.mpdiasbase AS mpdiasbase,        crmaeprbf.mpajuper AS mpajuper,        crmaeprbf.mpajuant AS mpajuant,        crmaeprbf.mpctacalint AS mpctacalint,        crmaeprbf.mpctacalcap AS mpctacalcap,        crmaeprbf.mpfcalcint AS mpfcalcint,        crmaeprbf.mpfcalccap AS mpfcalccap,        crmaeprbf.mpcuotaspagas AS mpcuotaspagas,        crmaeprbf.mpentermino AS mpentermino,        crmaeprbf.mpcodmora AS mpcodmora,        crmaeprbf.mpfpasemora AS mpfpasemora,        crmaeprbf.mpcodsitbco AS mpcodsitbco,        crmaeprbf.mpjur AS mpjur,        crmaeprbf.mpsisrel AS mpsisrel,        crmaeprbf.mpsucrel AS mpsucrel,        crmaeprbf.mptiporel AS mptiporel,        crmaeprbf.mpctarel AS mpctarel,        crmaeprbf.mpfvtoseg AS mpfvtoseg,        crmaeprbf.mpmontoseg AS mpmontoseg,        crmaeprbf.mpciaseg AS mpciaseg,        crmaeprbf.mpalicseg AS mpalicseg,        crmaeprbf.mpsuc AS mpsuc,        crmaeprbf.mplinea AS mplinea,        crmaeprbf.nro_operacion_origen AS nro_operacion_origen,        crmaeprbf.mptasapun AS mptasapun,        crmaeprbf.mpcodactbcra AS mpcodactbcra,        crmaeprbf.mpcodactbco AS mpcodactbco,        crmaeprbf.mporigrec AS mporigrec,        crmaeprbf.mpdestino AS mpdestino,        crmaeprbf.mpcalific AS mpcalific,        crmaeprbf.mpcircular AS mpcircular,        crmaeprbf.mpsector AS mpsector,        crmaeprbf.mparreglo AS mparreglo,        crmaeprbf.mpdebaut AS mpdebaut,        crmaeprbf.mpcomiscobaut AS mpcomiscobaut,        crmaeprbf.mpcomiscob AS mpcomiscob,        crmaeprbf.mpsellado AS mpsellado,        crmaeprbf.mpdocredes AS mpdocredes,        crmaeprbf.mplegajo AS mplegajo,        crmaeprbf.mpplanilla AS mpplanilla,        crmaeprbf.mpimportebase AS mpimportebase,        crmaeprbf.mptasabase AS mptasabase,        crmaeprbf.mpcodestado AS mpcodestado,        crmaeprbf.mpictipaju AS mpictipaju,        crmae ...
#     "affected_tables": [
#       "de_bsf_4con.productos_prestamos_dim_maestro"
#     ]
#   },
#   "de_bsj_3ref.productos_prestamos_dim_maestro": {
#     "database": "de_bsj_3ref",
#     "table_name": "productos_prestamos_dim_maestro",
#     "create_table": "",
#     "associated_term": "prest_productos_prestamos_dim_maestro_unisys",
#     "loading_query": "SELECT    pprpc.id_producto AS id_producto,    pprpc.id_moneda AS id_moneda_2,    ppmpr.id_moneda AS id_moneda_3,    ppaso.id_suc_cuenta AS id_suc_cuenta,    ppaso.id_num_cuenta AS id_num_cuenta,    ppmap.atributo_bcra AS id_sector,    ppmap.ejecutivo_cta AS ejecutivo_cta,    ppmap.marca_prestamo AS marca_prestamo,    ppmap.id_sistema_anterior AS id_sistema_anterior,    ppmap.id_moneda AS id_moneda,    ppmap.oficina AS id_sucursal,    ppmap.producto AS id_linea,    ppmap.nro_prestamo AS nro_operacion,    ppmap.nro_expediente_cfi_complemento AS nro_expediente_cfi_complemento,    ppmap.oficina_anterior_prestamo AS oficina_anterior_prestamo,    ppmap.nro_prestamo_viejo_1 AS nro_prestamo_viejo_1,    ppmap.nro_prestamo_viejo AS nro_prestamo_viejo,    ppmap.fecha_relativa_liquidacion AS fecha_de_liquidacion,    ppmap.id_cliente_core AS id_cliente_core,    ppmap.base_calculo AS base_calculo,    ppmap.debito_automatico AS debito_automatico,    ppmap.tratamiento_iva AS tratamiento_iva,    ppmap.oficina_debito_automatico AS oficina_debito_automatico,    ppmap.digito_verificador_debito_automatico AS digito_verificador_debito_automatico,    ppmap.nro_cta_deb_automatico AS nro_cta_deb_automatico,    ppmap.marca_en_uso AS marca_en_uso,    ppmap.mto_cotizacion_venta AS mto_cotizacion_venta,    ppmap.concepto_cta_acreditacion AS concepto_cta_acreditacion,    ppmap.sucursal_cta_acreditacion AS sucursal_cta_acreditacion,    ppmap.digito_verificador_cta_acreditacion AS digito_verificador_cta_acreditacion,    ppmap.nro_cta_acreditacion AS nro_cta_acreditacion,    ppmap.cant_cuotas AS cant_cuotas,    ppmap.cant_documentos AS cant_documentos,    ppmap.cant_clientes_mancomunados AS cant_clientes_mancomunados,    ppmap.dias_feriado_ultima_cuota AS dias_feriado_ultima_cuota,    ppmap.cant_cuotas_pagas AS cant_cuotas_pagas,    ppmap.cod_calificacion AS cod_calificacion,    ppmap.destino_fondos AS destino_fondos,    ppmap.id_formula AS id_formula,    ppmap.id_tasa_interes_punitorio AS id_tasa_interes_punitorio,    ppmap.id_tasa_interes_normal AS id_tasa_interes_normal,    ppmap.base_calculo_interes_punitorio AS base_calculo_interes_punitorio,    ppmap.base_calculo_interes_comp AS base_calculo_interes_comp,    ppmap.tipo_devengamiento AS tipo_devengamiento,    ppmap.id_cambio_situacion AS id_cambio_situacion,    ppmap.id_tasa_interes_vencido AS id_tasa_interes_vencido,    ppmap.id_forma_aplicacion_tasa AS id_forma_aplicacion_tasa,    ppmap.id_aplicacion_spread_tasa AS id_aplicacion_spread_tasa,    ppmap.id_sistema_amortizacion AS id_sistema_amortizacion,    ppmap.id_tratamiento_ley25063 AS id_tratamiento_ley25063,    ppmap.id_tratamiento_iva AS id_tratamiento_iva,    ppmap.dias_generar_cuota AS dias_generar_cuota,    ppmap.dias_gracia AS dias_gracia,    ppmap.dias_devengamiento_mes AS dias_devengamiento_mes,    ppmap.dias_periodo AS dias_periodo,    ppmap.dias_gracias_pago_cuotas AS dias_gracias_pago_cuotas,    ppmap.dias_gracias_restantes AS dias_gracias_restantes,    ppmap.dias_vto_cuotas AS dias_vto_cuotas,    ppmap.dias_reintento_debito_automatico AS dias_reintento_debito_automatico,    ppmap.dias_teoricos_periodo AS dias_teoricos_periodo,    ppmap.spread_de_tasa AS spread_de_tasa,    ppmap.fecha_cancelacion AS fecha_baja,    ppmap.fecha_ultimo_pago AS fecha_ultimo_pago,    ppmap.fecha_liquidacion AS fecha_alta,    ppmap.fecha_primer_vto AS fecha_primer_vto,    ppmap.fecha_vto_credito AS fecha_vto_credito,    ppmap.fecha_calculo_mora_fv AS fecha_calculo_mora_fv,    ppmap.fecha_cambio_estado AS fecha_cambio_estado,    ppmap.fecha_inicio_spread_tasa_vigente AS fecha_inicio_spread_tasa_vigente,    ppmap.fecha_inicio_tasa_vigente AS fecha_inicio_tasa_vigente,    ppmap.fecha_vto_proxima_factura AS fecha_vto_proxima_factura,    ppmap.fecha_ultimo_pago_cuota AS fecha_ultimo_pago_cuota,    ppmap.fecha_ultima_transaccion AS fecha_ultima_transaccion,    ppmap.fecha_vto_spread_tasa_vigente AS fecha_vto_spread_tasa_vigente,    ppmap.fecha_v ...
#     "affected_tables": [
#       "de_bsj_4con.productos_prestamos_dim_maestro"
#     ]
#   },
#   "de_ber_2cur.productos_pprpc": {
#     "database": "de_ber_2cur",
#     "table_name": "productos_pprpc",
#     "create_table": "",
#     "associated_term": "pprpc",
#     "loading_query": "SELECT GLB_DTIME, PCOTIPOPE, PCU_MONED, PCU_PRODU, PNU_ENTE, PNU_TRAMO, PPL_CREDI, PRE_LIQUI, PPOTBCUO1 FROM de_ber_1raw.sfb_pprpc WHERE fecha_proceso = '$FECHA_PROCESO';",
#     "affected_tables": [
#       "de_ber_3ref.productos_prestamos_dim_maestro"
#     ]
#   },
#   "de_bsc_2cur.productos_pprpc": {
#     "database": "de_bsc_2cur",
#     "table_name": "productos_pprpc",
#     "create_table": "",
#     "associated_term": "pprpc",
#     "loading_query": "SELECT GLB_DTIME, PCOTIPOPE, PCU_MONED, PCU_PRODU, PNU_ENTE, PNU_TRAMO, PPL_CREDI, PRE_LIQUI, PPOTBCUO1 FROM de_bsc_1raw.sfb_pprpc WHERE fecha_proceso = '$FECHA_PROCESO';",
#     "affected_tables": [
#       "de_bsc_3ref.productos_prestamos_dim_maestro"
#     ]
#   },
#   "de_bsj_2cur.productos_pprpc": {
#     "database": "de_bsj_2cur",
#     "table_name": "productos_pprpc",
#     "create_table": "",
#     "associated_term": "pprpc",
#     "loading_query": "SELECT GLB_DTIME, PCOTIPOPE, PCU_MONED, PCU_PRODU, PNU_ENTE, PNU_TRAMO, PPL_CREDI, PRE_LIQUI, PPOTBCUO1 FROM de_bsj_1raw.sfb_pprpc WHERE fecha_proceso = '$FECHA_PROCESO';",
#     "affected_tables": [
#       "de_bsj_3ref.productos_prestamos_dim_maestro"
#     ]
#   },
#   "de_ber_2cur.productos_ppaso": {
#     "database": "de_ber_2cur",
#     "table_name": "productos_ppaso",
#     "create_table": "",
#     "associated_term": "ppaso",
#     "loading_query": "SELECT  CAST(glb_dtime AS BIGINT ) AS id_registro, CAST(aferelsol AS INT ) AS fecha_relativa_alta_solic, CAST(dco_ofici AS INT ) AS id_suc_origen, CAST(dco_usuar AS VARCHAR(10) ) AS usuario_autorizador, CAST(lcu_ofici AS INT ) AS id_oficina_lin_cred, CAST(lcunumcue AS INT ) AS num_cta_lin_cred, CAST(pcoejecue AS VARCHAR(10) ) AS id_oficial_cuenta, CAST(pcoestcue AS INT ) AS estado_prestamo, CAST(pcosistem AS VARCHAR(3) ) AS id_cod_sist_anterior, CAST(pcu_moned AS INT ) AS id_moneda, CAST(pcu_numwf AS INT ) AS num_ref_workflow, CAST(pcu_ofici AS INT ) AS id_suc_cuenta, CAST(pcu_produ AS INT ) AS id_producto, CAST(pcunumcue AS INT ) AS id_num_cuenta, CAST(pnuexpcfa AS VARCHAR(2) ) AS nro_exp_cfi_complemento, CAST(pnuexpcfi AS INT ) AS nro_expediente_cfi, CAST(pnuofivie AS INT ) AS oficina_anterior_prestamo, CAST(pnuprevi1 AS INT ) AS nro_prestamo_viejo2, CAST(pnuprevie AS INT ) AS nro_prestamo_viejo1, CAST(pre_liqui AS INT ) AS fecha_relativa_liquidacion, CAST(psecesion AS VARCHAR(1) ) AS senial_cesion_valores, CAST(aco_conce AS INT ) AS concep_deb_autom, CAST(aco_concx AS INT ) AS concep_cta_liquidacion, CAST(aco_digvx AS INT ) AS digito_verif_cta_liq, CAST(aco_numcx AS INT ) AS id_cta_verificacion, CAST(aco_oficx AS INT ) AS id_suc_liquidacion, CAST(acoatbcra AS INT ) AS id_atributo_bcra, CAST(acotraiva AS INT ) AS tratamiento_iva, CAST(acu_ofici AS INT ) AS id_ofic_is_deb_auto, CAST(acudigver AS INT ) AS digito_verif_is_deb_auto, CAST(acunumcue AS INT ) AS num_cta_deb_auto, CAST(from_unixtime(unix_timestamp(afe_solic, 'yyyyMMdd')) AS DATE ) AS fecha_alta_solic, CAST(ava_venta AS DECIMAL(19,2) ) AS mto_cotizacion_venta, CAST(ccu_conce AS INT ) AS concepto_cta_acreditacion, CAST(ccu_ofici AS INT ) AS id_suc_cta_acreditacion, CAST(ccudigver AS INT ) AS digito_verificador_cta_acred, CAST(ccunumcue AS INT ) AS id_num_cta_acreditacion, CAST(hcu_ofici AS INT ) AS sucursal_cuenta, CAST(lcu_moned AS INT ) AS id_moneda_lin_credito, CAST(lcu_produ AS INT ) AS id_producto_lin_credito, CAST(lcudigver AS INT ) AS digito_verificador_lin_cred, CAST(ncogarpen1 AS INT ) AS id_garantia_pend_1, CAST(ncogarpen2 AS INT ) AS id_garantia_pend_2, CAST(ncogarpen3 AS INT ) AS id_garantia_pend_3, CAST(ncogarpre1 AS INT ) AS id_garantia_present_1, CAST(ncogarpre2 AS INT ) AS id_garantia_present_2, CAST(ncogarpre3 AS INT ) AS id_garantia_present_3, CAST(pcn_autor AS INT ) AS cant_autorizantes, CAST(pcn_cuota AS INT ) AS cant_cuotas, CAST(pcn_docum AS INT ) AS cant_documentos, CAST(pcncliman AS INT ) AS cant_clientes_mancomunados, CAST(pcnctacon AS INT ) AS cant_cuotas_condonar, CAST(pcnctapag AS INT ) AS cuotas_pagadas, CAST(pcndiaatr AS INT ) AS cant_dias_atraso, CAST(pcndocpre AS INT ) AS cant_documentos_presen, CAST(pcninsreq AS INT ) AS instrumentacin_requerida, CAST(pco_aprob AS VARCHAR(10) ) AS usuario_aprobador_solicitud, CAST(pco_auto1 AS VARCHAR(10) ) AS autorizante_1, CAST(pco_auto2 AS VARCHAR(10) ) AS autorizante_2, CAST(pco_auto3 AS VARCHAR(10) ) AS autorizante_3, CAST(pco_auto4 AS VARCHAR(10) ) AS autorizante_4, CAST(pco_auto5 AS VARCHAR(10) ) AS autorizante_5, CAST(pco_auto6 AS VARCHAR(10) ) AS autorizante_6, CAST(pco_auto7 AS VARCHAR(10) ) AS autorizante_7, CAST(pco_calif AS INT ) AS id_cod_calificacion, CAST(pco_desti AS INT ) AS destino_fondos, CAST(pco_empre AS INT ) AS id_empresa, CAST(pco_formu AS INT ) AS id_formula, CAST(pco_mora AS INT ) AS id_tasa_mora, CAST(pco_param AS INT ) AS id_params_prod_alta_simplif, CAST(pco_paris AS INT ) AS sin_uso, CAST(pco_tasa AS INT ) AS id_tasa, CAST(pco_usuwf AS VARCHAR(10) ) AS usuario_workflow, CAST(pcobaprve AS INT ) AS base_cobro_int_compensatorios, CAST(pcobasmor AS INT ) AS base_cobro_int_punitorios, CAST(pcocamsit AS INT ) AS id_cambio_situacion, CAST(pcoconrel AS INT ) AS concepto_cta_relacionada, CAST(pcoctarel AS INT ) AS id_cta_relacionada, CAST(pcodigrel AS INT ) AS digito_verif_cta_relacionada, CAST(pcoejeori AS VARCHAR(10) ) AS oficina_cta_origen, CAST(pcoimputa  ...
#     "affected_tables": [
#       "de_ber_3ref.productos_prestamos_dim_maestro"
#     ]
#   },
#   "de_bsc_2cur.productos_ppaso": {
#     "database": "de_bsc_2cur",
#     "table_name": "productos_ppaso",
#     "create_table": "",
#     "associated_term": "ppaso",
#     "loading_query": "SELECT  CAST(glb_dtime AS BIGINT ) AS id_registro, CAST(aferelsol AS INT ) AS fecha_relativa_alta_solic, CAST(dco_ofici AS INT ) AS id_suc_origen, CAST(dco_usuar AS VARCHAR(10) ) AS usuario_autorizador, CAST(lcu_ofici AS INT ) AS id_oficina_lin_cred, CAST(lcunumcue AS INT ) AS num_cta_lin_cred, CAST(pcoejecue AS VARCHAR(10) ) AS id_oficial_cuenta, CAST(pcoestcue AS INT ) AS estado_prestamo, CAST(pcosistem AS VARCHAR(3) ) AS id_cod_sist_anterior, CAST(pcu_moned AS INT ) AS id_moneda, CAST(pcu_numwf AS INT ) AS num_ref_workflow, CAST(pcu_ofici AS INT ) AS id_suc_cuenta, CAST(pcu_produ AS INT ) AS id_producto, CAST(pcunumcue AS INT ) AS id_num_cuenta, CAST(pnuexpcfa AS VARCHAR(2) ) AS nro_exp_cfi_complemento, CAST(pnuexpcfi AS INT ) AS nro_expediente_cfi, CAST(pnuofivie AS INT ) AS oficina_anterior_prestamo, CAST(pnuprevi1 AS INT ) AS nro_prestamo_viejo2, CAST(pnuprevie AS INT ) AS nro_prestamo_viejo1, CAST(pre_liqui AS INT ) AS fecha_relativa_liquidacion, CAST(psecesion AS VARCHAR(1) ) AS senial_cesion_valores, CAST(aco_conce AS INT ) AS concep_deb_autom, CAST(aco_concx AS INT ) AS concep_cta_liquidacion, CAST(aco_digvx AS INT ) AS digito_verif_cta_liq, CAST(aco_numcx AS INT ) AS id_cta_verificacion, CAST(aco_oficx AS INT ) AS id_suc_liquidacion, CAST(acoatbcra AS INT ) AS id_atributo_bcra, CAST(acotraiva AS INT ) AS tratamiento_iva, CAST(acu_ofici AS INT ) AS id_ofic_is_deb_auto, CAST(acudigver AS INT ) AS digito_verif_is_deb_auto, CAST(acunumcue AS INT ) AS num_cta_deb_auto, CAST(from_unixtime(unix_timestamp(afe_solic, 'yyyyMMdd')) AS DATE ) AS fecha_alta_solic, CAST(ava_venta AS DECIMAL(19,2) ) AS mto_cotizacion_venta, CAST(ccu_conce AS INT ) AS concepto_cta_acreditacion, CAST(ccu_ofici AS INT ) AS id_suc_cta_acreditacion, CAST(ccudigver AS INT ) AS digito_verificador_cta_acred, CAST(ccunumcue AS INT ) AS id_num_cta_acreditacion, CAST(hcu_ofici AS INT ) AS sucursal_cuenta, CAST(lcu_moned AS INT ) AS id_moneda_lin_credito, CAST(lcu_produ AS INT ) AS id_producto_lin_credito, CAST(lcudigver AS INT ) AS digito_verificador_lin_cred, CAST(ncogarpen1 AS INT ) AS id_garantia_pend_1, CAST(ncogarpen2 AS INT ) AS id_garantia_pend_2, CAST(ncogarpen3 AS INT ) AS id_garantia_pend_3, CAST(ncogarpre1 AS INT ) AS id_garantia_present_1, CAST(ncogarpre2 AS INT ) AS id_garantia_present_2, CAST(ncogarpre3 AS INT ) AS id_garantia_present_3, CAST(pcn_autor AS INT ) AS cant_autorizantes, CAST(pcn_cuota AS INT ) AS cant_cuotas, CAST(pcn_docum AS INT ) AS cant_documentos, CAST(pcncliman AS INT ) AS cant_clientes_mancomunados, CAST(pcnctacon AS INT ) AS cant_cuotas_condonar, CAST(pcnctapag AS INT ) AS cuotas_pagadas, CAST(pcndiaatr AS INT ) AS cant_dias_atraso, CAST(pcndocpre AS INT ) AS cant_documentos_presen, CAST(pcninsreq AS INT ) AS instrumentacin_requerida, CAST(pco_aprob AS VARCHAR(10) ) AS usuario_aprobador_solicitud, CAST(pco_auto1 AS VARCHAR(10) ) AS autorizante_1, CAST(pco_auto2 AS VARCHAR(10) ) AS autorizante_2, CAST(pco_auto3 AS VARCHAR(10) ) AS autorizante_3, CAST(pco_auto4 AS VARCHAR(10) ) AS autorizante_4, CAST(pco_auto5 AS VARCHAR(10) ) AS autorizante_5, CAST(pco_auto6 AS VARCHAR(10) ) AS autorizante_6, CAST(pco_auto7 AS VARCHAR(10) ) AS autorizante_7, CAST(pco_calif AS INT ) AS id_cod_calificacion, CAST(pco_desti AS INT ) AS destino_fondos, CAST(pco_empre AS INT ) AS id_empresa, CAST(pco_formu AS INT ) AS id_formula, CAST(pco_mora AS INT ) AS id_tasa_mora, CAST(pco_param AS INT ) AS id_params_prod_alta_simplif, CAST(pco_paris AS INT ) AS sin_uso, CAST(pco_tasa AS INT ) AS id_tasa, CAST(pco_usuwf AS VARCHAR(10) ) AS usuario_workflow, CAST(pcobaprve AS INT ) AS base_cobro_int_compensatorios, CAST(pcobasmor AS INT ) AS base_cobro_int_punitorios, CAST(pcocamsit AS INT ) AS id_cambio_situacion, CAST(pcoconrel AS INT ) AS concepto_cta_relacionada, CAST(pcoctarel AS INT ) AS id_cta_relacionada, CAST(pcodigrel AS INT ) AS digito_verif_cta_relacionada, CAST(pcoejeori AS VARCHAR(10) ) AS oficina_cta_origen, CAST(pcoimputa  ...
#     "affected_tables": [
#       "de_bsc_3ref.productos_prestamos_dim_maestro"
#     ]
#   },
#   "de_bsj_2cur.productos_ppaso": {
#     "database": "de_bsj_2cur",
#     "table_name": "productos_ppaso",
#     "create_table": "",
#     "associated_term": "ppaso",
#     "loading_query": "SELECT  CAST(glb_dtime AS BIGINT ) AS id_registro, CAST(aferelsol AS INT ) AS fecha_relativa_alta_solic, CAST(dco_ofici AS INT ) AS id_suc_origen, CAST(dco_usuar AS VARCHAR(10) ) AS usuario_autorizador, CAST(lcu_ofici AS INT ) AS id_oficina_lin_cred, CAST(lcunumcue AS INT ) AS num_cta_lin_cred, CAST(pcoejecue AS VARCHAR(10) ) AS id_oficial_cuenta, CAST(pcoestcue AS INT ) AS estado_prestamo, CAST(pcosistem AS VARCHAR(3) ) AS id_cod_sist_anterior, CAST(pcu_moned AS INT ) AS id_moneda, CAST(pcu_numwf AS INT ) AS num_ref_workflow, CAST(pcu_ofici AS INT ) AS id_suc_cuenta, CAST(pcu_produ AS INT ) AS id_producto, CAST(pcunumcue AS INT ) AS id_num_cuenta, CAST(pnuexpcfa AS VARCHAR(2) ) AS nro_exp_cfi_complemento, CAST(pnuexpcfi AS INT ) AS nro_expediente_cfi, CAST(pnuofivie AS INT ) AS oficina_anterior_prestamo, CAST(pnuprevi1 AS INT ) AS nro_prestamo_viejo2, CAST(pnuprevie AS INT ) AS nro_prestamo_viejo1, CAST(pre_liqui AS INT ) AS fecha_relativa_liquidacion, CAST(psecesion AS VARCHAR(1) ) AS senial_cesion_valores, CAST(aco_conce AS INT ) AS concep_deb_autom, CAST(aco_concx AS INT ) AS concep_cta_liquidacion, CAST(aco_digvx AS INT ) AS digito_verif_cta_liq, CAST(aco_numcx AS INT ) AS id_cta_verificacion, CAST(aco_oficx AS INT ) AS id_suc_liquidacion, CAST(acoatbcra AS INT ) AS id_atributo_bcra, CAST(acotraiva AS INT ) AS tratamiento_iva, CAST(acu_ofici AS INT ) AS id_ofic_is_deb_auto, CAST(acudigver AS INT ) AS digito_verif_is_deb_auto, CAST(acunumcue AS INT ) AS num_cta_deb_auto, CAST(from_unixtime(unix_timestamp(afe_solic, 'yyyyMMdd')) AS DATE ) AS fecha_alta_solic, CAST(ava_venta AS DECIMAL(19,2) ) AS mto_cotizacion_venta, CAST(ccu_conce AS INT ) AS concepto_cta_acreditacion, CAST(ccu_ofici AS INT ) AS id_suc_cta_acreditacion, CAST(ccudigver AS INT ) AS digito_verificador_cta_acred, CAST(ccunumcue AS INT ) AS id_num_cta_acreditacion, CAST(hcu_ofici AS INT ) AS sucursal_cuenta, CAST(lcu_moned AS INT ) AS id_moneda_lin_credito, CAST(lcu_produ AS INT ) AS id_producto_lin_credito, CAST(lcudigver AS INT ) AS digito_verificador_lin_cred, CAST(ncogarpen1 AS INT ) AS id_garantia_pend_1, CAST(ncogarpen2 AS INT ) AS id_garantia_pend_2, CAST(ncogarpen3 AS INT ) AS id_garantia_pend_3, CAST(ncogarpre1 AS INT ) AS id_garantia_present_1, CAST(ncogarpre2 AS INT ) AS id_garantia_present_2, CAST(ncogarpre3 AS INT ) AS id_garantia_present_3, CAST(pcn_autor AS INT ) AS cant_autorizantes, CAST(pcn_cuota AS INT ) AS cant_cuotas, CAST(pcn_docum AS INT ) AS cant_documentos, CAST(pcncliman AS INT ) AS cant_clientes_mancomunados, CAST(pcnctacon AS INT ) AS cant_cuotas_condonar, CAST(pcnctapag AS INT ) AS cuotas_pagadas, CAST(pcndiaatr AS INT ) AS cant_dias_atraso, CAST(pcndocpre AS INT ) AS cant_documentos_presen, CAST(pcninsreq AS INT ) AS instrumentacin_requerida, CAST(pco_aprob AS VARCHAR(10) ) AS usuario_aprobador_solicitud, CAST(pco_auto1 AS VARCHAR(10) ) AS autorizante_1, CAST(pco_auto2 AS VARCHAR(10) ) AS autorizante_2, CAST(pco_auto3 AS VARCHAR(10) ) AS autorizante_3, CAST(pco_auto4 AS VARCHAR(10) ) AS autorizante_4, CAST(pco_auto5 AS VARCHAR(10) ) AS autorizante_5, CAST(pco_auto6 AS VARCHAR(10) ) AS autorizante_6, CAST(pco_auto7 AS VARCHAR(10) ) AS autorizante_7, CAST(pco_calif AS INT ) AS id_cod_calificacion, CAST(pco_desti AS INT ) AS destino_fondos, CAST(pco_empre AS INT ) AS id_empresa, CAST(pco_formu AS INT ) AS id_formula, CAST(pco_mora AS INT ) AS id_tasa_mora, CAST(pco_param AS INT ) AS id_params_prod_alta_simplif, CAST(pco_paris AS INT ) AS sin_uso, CAST(pco_tasa AS INT ) AS id_tasa, CAST(pco_usuwf AS VARCHAR(10) ) AS usuario_workflow, CAST(pcobaprve AS INT ) AS base_cobro_int_compensatorios, CAST(pcobasmor AS INT ) AS base_cobro_int_punitorios, CAST(pcocamsit AS INT ) AS id_cambio_situacion, CAST(pcoconrel AS INT ) AS concepto_cta_relacionada, CAST(pcoctarel AS INT ) AS id_cta_relacionada, CAST(pcodigrel AS INT ) AS digito_verif_cta_relacionada, CAST(pcoejeori AS VARCHAR(10) ) AS oficina_cta_origen, CAST(pcoimputa  ...
#     "affected_tables": [
#       "de_bsj_3ref.productos_prestamos_dim_maestro"
#     ]
#   },
#   "de_ber_2cur.productos_ppmap": {
#     "database": "de_ber_2cur",
#     "table_name": "productos_ppmap",
#     "create_table": "",
#     "associated_term": "ppmap",
#     "loading_query": "select    glb_dtime as clave_registro,    acoatbcra as atributo_bcra,    pcoejecue as ejecutivo_cta,    pcoestcue as marca_prestamo,    pcosistem as id_sistema_anterior,    pcu_moned as id_moneda,    pcu_ofici as oficina,    pcu_produ as producto,    pcunumcue as nro_prestamo,    pnuexpcfa as nro_expediente_cfi_complemento,    pnuexpcfi as nro_expediente_cfi,    pnuofivie as oficina_anterior_prestamo,    pnuprevi1 as nro_prestamo_viejo_1,    pnuprevie as nro_prestamo_viejo,    pre_liqui as fecha_relativa_liquidacion,    sco_ident as id_cliente_core,    aco_bcalc as base_calculo,    aco_conce as debito_automatico,    acotraiva as tratamiento_iva,    acu_ofici as oficina_debito_automatico,    acudigver as digito_verificador_debito_automatico,    acunumcue as nro_cta_deb_automatico,    ase_enuso as marca_en_uso,    case when replace(ava_venta, ',', '.') like '.%' then replace(concat('0', ava_venta),',','.') else replace(ava_venta, ',', '.') end as mto_cotizacion_venta,    ccu_conce as concepto_cta_acreditacion,    ccu_ofici as sucursal_cta_acreditacion,    ccudigver as digito_verificador_cta_acreditacion,    ccunumcue as nro_cta_acreditacion,    pcn_cuota as cant_cuotas,    pcn_docum as cant_documentos,    pcncliman as cant_clientes_mancomunados,    pcnctacon as cant_cuotas_condonar,    pcnctapag as cant_cuotas_pagadas,    pcnctcoan as cant_cuotas_pagadas_termino,    pcndiaatr as dias_atraso,    pcndiafer as dias_feriado_ultima_cuota,    pcndiaofe as cant_dias_oferta,    pcnfacpag as cant_cuotas_pagas,    pco_calif as cod_calificacion,    pco_desti as destino_fondos,    pco_empre as cod_empresa,    pco_formu as id_formula,    pco_mora as id_tasa_interes_punitorio,    pco_tasa as id_tasa_interes_normal,    pcobacamo as base_calculo_interes_punitorio,    pcobacavd as base_calculo_interes_comp,    pcocaldev as tipo_devengamiento,    pcocamsit as id_cambio_situacion,    pcotasvdo as id_tasa_interes_vencido,    pcotip1ra as id_forma_pago_ajuste,    pcotip2da as id_forma_aplicacion_tasa,    pcotip2df as id_aplicacion_tasa_futura,    pcotip3ra as id_aplicacion_spread_tasa,    pcotip3rf as id_aplicacion_spread_tasa_futura,    pcotipcuo as id_sistema_amortizacion,    pcotraimp as id_tratamiento_ley25063,    pcotraiva as id_tratamiento_iva,    pdi_factu as dias_generar_cuota,    pdi_graci as dias_gracia,    pdidiames as dias_devengamiento_mes,    pdidiaper as dias_periodo,    pdigracuo as dias_gracias_pago_cuotas,    pdigrares as dias_gracias_restantes,    pdipagfac as dias_vto_cuotas,    pdireinte as dias_reintento_debito_automatico,    pditeoper as dias_teoricos_periodo,    pdivenimp as dias_vencido_impago,    pfasprtas as spread_de_tasa,    pfasptafu as spread_de_tasa_futura,    to_date(     from_unixtime(       unix_timestamp(         cast(           from_unixtime(             unix_timestamp(               SUBSTR(                 CONCAT('000', pfe_cance),                  -6               ),                'ddMMyy'             ),              'yyyyMMdd'           ) AS varchar(8)         ),          'yyyyMMdd'       ),        'yyyy-MM-dd'     )   ) as fecha_cancelacion,    to_date(     from_unixtime(       unix_timestamp(         cast(           from_unixtime(             unix_timestamp(               SUBSTR(                 CONCAT('000', pfe_estad),                  -6               ),                'ddMMyy'             ),              'yyyyMMdd'           ) AS varchar(8)         ),          'yyyyMMdd'       ),        'yyyy-MM-dd'     )   ) as fecha_ultimo_pago,    to_date(     from_unixtime(       unix_timestamp(         cast(           from_unixtime(             unix_timestamp(               SUBSTR(                 CONCAT('000', pfe_liqui),                  -6               ),                'ddMMyy'             ),              'yyyyMMdd'           ) AS varchar(8)         ),          'yyyyMMdd'       ),        'yyyy-MM-dd'     )   ) as fecha_liquidacion,    to_date(     from_unixtime(       unix_timestamp(      ...
#     "affected_tables": [
#       "de_ber_3ref.productos_prestamos_dim_maestro",
#       "de_ber_3ref.productos_prestamos_ft",
#       "de_ber_3ref.productos_prestamos_dim"
#     ]
#   },
#   "de_bsc_2cur.productos_ppmap": {
#     "database": "de_bsc_2cur",
#     "table_name": "productos_ppmap",
#     "create_table": "",
#     "associated_term": "ppmap",
# ...
#     "affected_tables": [
#       "de_bsf_2cur.ft_ant_neg_embargos",
#       "de_bsf_3ref.abt_persona_perfil_crediticio_online"
#     ]
#   },
#   "de_bsj_2cur.ft_ant_neg_embargos": {
#     "database": "de_bsj_2cur",
#     "table_name": "ft_ant_neg_embargos",
#     "create_table": "",
#     "associated_term": "riesgos_embargos_sfb_ahabl",
#     "loading_query": "WITH pre_acmol1 AS (SELECT *, row_number() over (partition BY sco_ident, ccunumcue ORDER BY fecha_proceso DESC nulls LAST) AS fila1 FROM de_bsj_1raw.sfb_acmol), pre_acmol2 AS (SELECT * FROM pre_acmol1 WHERE fila1 = 1 ), acmol AS (SELECT * FROM pre_acmol2 WHERE cast(pre_acmol2.ccoestcue AS int) = 1 ), acabl AS (SELECT * FROM de_bsj_1raw.sfb_acabl WHERE fecha_proceso = '$FECHA_PROCESO' ), cc AS (SELECT 'CUENTA CORRIENTE' AS fuente_registro, cast(acabl.ccunumcue AS bigint) AS nro_cta_cte, cast(acabl.ccudigver AS int) AS nro_dig_verificador, trim(acmol.sco_ident) AS id_cliente_core, trim(acabl.ccu_ofici) AS id_sucursal, cast(aco_bloqu AS int) AS id_embargo, cast(ccoestblo AS int) AS id_estado_embargo, trim(acabl.estado) AS estado, from_unixtime(unix_timestamp(lpad(cfeiniblo,6,'0'),'ddMMyy'),'yyyy-MM-dd') AS fecha_alta_embargo, concat('20',from_unixtime(unix_timestamp(lpad(cfeexpblo,6,'0'),'ddMMyy'),'yy-MM-dd')) AS fecha_vto_embargo, cast(replace(tva_movim, ',', '.') AS decimal(16,2)) AS mto_embargo, trim(tnudoctra) AS nro_documento, trim(acabl.glb_dtime) AS glb_dtime, cast(acmol.ccoestcue AS int) AS estadocuenta FROM acabl JOIN acmol ON cast(acabl.CCUNUMCUE AS bigint) = cast(acmol.ccunumcue AS bigint) AND cast(acabl.ccudigver AS int) = cast(acmol.ccudigver AS int) AND cast(acabl.ccu_ofici AS int) = cast(acmol.ccu_ofici AS int)), pre_ahmol1 AS (SELECT *, row_number() over (partition BY sco_ident, hcunumcue ORDER BY fecha_proceso DESC nulls LAST) AS fila1 FROM de_bsj_1raw.sfb_ahmol), pre_ahmol2 as (SELECT * FROM pre_ahmol1 WHERE fila1 = 1 ), ahmol AS (SELECT * FROM pre_ahmol2 WHERE cast(pre_ahmol2.hcoestcue AS int) = 1 ), ahabl AS (SELECT * FROM de_bsj_1raw.sfb_ahabl WHERE fecha_proceso = '$FECHA_PROCESO' ), ca AS (SELECT 'CAJA DE AHORROS' AS fuente_registro, cast(ahabl.hcunumcue AS bigint) AS nro_cta_cte, cast(ahabl.hcudigver AS int) AS nro_dig_verificador, trim(ahmol.sco_ident) AS id_cliente_core, trim(ahabl.hcu_ofici) AS id_sucursal, cast(aco_bloqu AS int) AS id_embargo, cast(hcoestblo AS int) AS id_estado_embargo, trim(ahabl.estado) AS estado, from_unixtime(unix_timestamp(lpad(hfeiniblo,6,'0'),'ddMMyy'),'yyyy-MM-dd') AS fecha_alta_embargo, concat('20',from_unixtime(unix_timestamp(lpad(hfeexpblo,6,'0'),'ddMMyy'),'yy-MM-dd')) AS fecha_vto_embargo, cast(replace(tva_movim, ',', '.') AS decimal(16,2)) AS mto_embargo, trim(tnudoctra) AS nro_documento, trim(ahabl.glb_dtime) AS glb_dtime, cast(ahmol.hcoestcue AS int) AS estadocuenta FROM ahabl JOIN ahmol ON cast(ahabl.hCUNUMCUE AS bigint) = cast(ahmol.hcunumcue AS bigint) AND cast(ahabl.hcudigver AS int) = cast(ahmol.hcudigver AS int) AND cast(ahabl.hcu_ofici AS int) = cast(ahmol.hcu_ofici AS int)), bsado AS (SELECT id_cliente_core, id_tipo_doc, nro_documento AS id_persona, pais, nro_version, fecha_proceso FROM de_bsj_2cur.rel_cliente_core_documentos AS bsado WHERE cast(id_tipo_doc AS int) IN $ID_TIPO_DOC AND length(cast(bsado.nro_documento AS string)) = 11 ), FINAL AS (SELECT DISTINCT concat(cast(bsado.id_persona AS string), '-', cast(cc.nro_cta_cte AS string), '-', cast(cc.id_embargo AS string), '-', lpad(cc.fecha_alta_embargo,6,'0'), '-', cast(cc.nro_documento AS string)) AS pk, cast(bsado.id_persona AS bigint) AS id_persona, cc.estadocuenta, cc.fuente_registro, cc.nro_cta_cte, cc.nro_dig_verificador, cc.id_cliente_core, cc.id_sucursal, cc.id_embargo, cc.id_estado_embargo, cc.estado, cc.fecha_alta_embargo, cc.fecha_vto_embargo, cc.mto_embargo, cc.nro_documento, cc.glb_dtime FROM cc JOIN bsado ON cast(cc.id_cliente_core AS bigint) = cast(bsado.id_cliente_core AS bigint) UNION SELECT DISTINCT concat(cast(bsado.id_persona AS string), '-', cast(ca.nro_cta_cte AS string), '-', cast(ca.id_embargo AS string), '-', lpad(ca.fecha_alta_embargo,6,'0'), '-', cast(ca.nro_documento AS string)) AS pk, cast(bsado.id_persona AS bigint) AS id_persona, ca.estadocuenta, ca.fuente_registro, ca.nro_cta_cte, ca.nro_dig_verificador, ca.id_cliente_core, ca.id_sucursal, ca.id_embargo, ca ...
#     "affected_tables": [
#       "de_bsj_2cur.ft_ant_neg_embargos",
#       "de_bsj_3ref.abt_persona_perfil_crediticio_online"
#     ]
#   },
#   "de_ber_2cur.productos_ahabl": {
#     "database": "de_ber_2cur",
#     "table_name": "productos_ahabl",
#     "create_table": "",
#     "associated_term": "ahabl",
#     "loading_query": "SELECT      glb_dtime AS clave_registro,        hcu_ofici AS id_sucursal,        hcunumcue AS nro_cta,        tnudoctra AS nro_doc_operacion,        aco_bloqu AS id_bloqueo,        Estado AS estado,        hcoestblo AS id_estado_bloqueo,        hcudigver AS digito_verif_cta,        CASE            WHEN to_date(from_unixtime(unix_timestamp(cast(from_unixtime(unix_timestamp(SUBSTR(CONCAT('000', hfeexpblo), -6), 'ddMMyy'), 'yyyyMMdd') AS varchar(8)), 'yyyyMMdd'),\"yyyy-MM-dd\")) < to_date(\"2000-01-01\") THEN add_months(to_date(from_unixtime(unix_timestamp(cast(from_unixtime(unix_timestamp(SUBSTR(CONCAT('000', sfb_ahabl.hfeexpblo), -6), 'ddMMyy'), 'yyyyMMdd') AS varchar(8)), 'yyyyMMdd'),\"yyyy-MM-dd\")), 1200)            ELSE to_date(from_unixtime(unix_timestamp(cast(from_unixtime(unix_timestamp(SUBSTR(CONCAT('000', hfeexpblo), -6), 'ddMMyy'), 'yyyyMMdd') AS varchar(8)), 'yyyyMMdd'),\"yyyy-MM-dd\"))        END AS fecha_exp_bloqueo,        to_date(from_unixtime(unix_timestamp(cast(from_unixtime(unix_timestamp(SUBSTR(CONCAT('000', hfeiniblo), -6), 'ddMMyy'), 'yyyyMMdd') AS varchar(8)), 'yyyyMMdd'),\"yyyy-MM-dd\")) AS fecha_inicio_bloqueo,        cast(replace(tva_movim,\",\",\".\") AS decimal(14,2)) AS valor_movimiento FROM de_ber_1raw.sfb_ahabl WHERE fecha_proceso = '$FECHA_PROCESO'",
#     "affected_tables": []
#   },
#   "de_bsc_2cur.productos_ahabl": {
#     "database": "de_bsc_2cur",
#     "table_name": "productos_ahabl",
#     "create_table": "",
#     "associated_term": "ahabl",
#     "loading_query": "SELECT      glb_dtime AS clave_registro,        hcu_ofici AS id_sucursal,        hcunumcue AS nro_cta,        tnudoctra AS nro_doc_operacion,        aco_bloqu AS id_bloqueo,        Estado AS estado,        hcoestblo AS id_estado_bloqueo,        hcudigver AS digito_verif_cta,        CASE            WHEN to_date(from_unixtime(unix_timestamp(cast(from_unixtime(unix_timestamp(SUBSTR(CONCAT('000', hfeexpblo), -6), 'ddMMyy'), 'yyyyMMdd') AS varchar(8)), 'yyyyMMdd'),\"yyyy-MM-dd\")) < to_date(\"2000-01-01\") THEN add_months(to_date(from_unixtime(unix_timestamp(cast(from_unixtime(unix_timestamp(SUBSTR(CONCAT('000', sfb_ahabl.hfeexpblo), -6), 'ddMMyy'), 'yyyyMMdd') AS varchar(8)), 'yyyyMMdd'),\"yyyy-MM-dd\")), 1200)            ELSE to_date(from_unixtime(unix_timestamp(cast(from_unixtime(unix_timestamp(SUBSTR(CONCAT('000', hfeexpblo), -6), 'ddMMyy'), 'yyyyMMdd') AS varchar(8)), 'yyyyMMdd'),\"yyyy-MM-dd\"))        END AS fecha_exp_bloqueo,        to_date(from_unixtime(unix_timestamp(cast(from_unixtime(unix_timestamp(SUBSTR(CONCAT('000', hfeiniblo), -6), 'ddMMyy'), 'yyyyMMdd') AS varchar(8)), 'yyyyMMdd'),\"yyyy-MM-dd\")) AS fecha_inicio_bloqueo,        cast(replace(tva_movim,\",\",\".\") AS decimal(14,2)) AS valor_movimiento FROM de_bsc_1raw.sfb_ahabl WHERE fecha_proceso = '$FECHA_PROCESO'",
#     "affected_tables": []
#   },
#   "de_bsj_2cur.productos_ahabl": {
#     "database": "de_bsj_2cur",
#     "table_name": "productos_ahabl",
#     "create_table": "",
#     "associated_term": "ahabl",
#     "loading_query": "SELECT      glb_dtime AS clave_registro,        hcu_ofici AS id_sucursal,        hcunumcue AS nro_cta,        tnudoctra AS nro_doc_operacion,        aco_bloqu AS id_bloqueo,        Estado AS estado,        hcoestblo AS id_estado_bloqueo,        hcudigver AS digito_verif_cta,        CASE            WHEN to_date(from_unixtime(unix_timestamp(cast(from_unixtime(unix_timestamp(SUBSTR(CONCAT('000', hfeexpblo), -6), 'ddMMyy'), 'yyyyMMdd') AS varchar(8)), 'yyyyMMdd'),\"yyyy-MM-dd\")) < to_date(\"2000-01-01\") THEN add_months(to_date(from_unixtime(unix_timestamp(cast(from_unixtime(unix_timestamp(SUBSTR(CONCAT('000', sfb_ahabl.hfeexpblo), -6), 'ddMMyy'), 'yyyyMMdd') AS varchar(8)), 'yyyyMMdd'),\"yyyy-MM-dd\")), 1200)            ELSE to_date(from_unixtime(unix_timestamp(cast(from_unixtime(unix_timestamp(SUBSTR(CONCAT('000', hfeexpblo), -6), 'ddMMyy'), 'yyyyMMdd') AS varchar(8)), 'yyyyMMdd'),\"yyyy-MM-dd\"))        END AS fecha_exp_bloqueo,        to_date(from_unixtime(unix_timestamp(cast(from_unixtime(unix_timestamp(SUBSTR(CONCAT('000', hfeiniblo), -6), 'ddMMyy'), 'yyyyMMdd') AS varchar(8)), 'yyyyMMdd'),\"yyyy-MM-dd\")) AS fecha_inicio_bloqueo,        cast(replace(tva_movim,\",\",\".\") AS decimal(14,2)) AS valor_movimiento FROM de_bsj_1raw.sfb_ahabl WHERE fecha_proceso = '$FECHA_PROCESO'",
#     "affected_tables": []
#   },
#   "de_bsf_1raw.soj_embargos": {
#     "database": "de_bsf_1raw",
#     "table_name": "soj_embargos",
#     "create_table": "",
#     "associated_term": "sbi_bsf_embargos_individuos",
#     "loading_query": null,
#     "affected_tables": [
#       "de_bsf_2cur.ft_ant_neg_embargos",
#       "de_bsf_2cur.dim_ant_negativos_embargos"
#     ]
#   },
#   "de_bsf_2cur.dim_ant_negativos_embargos": {
#     "database": "de_bsf_2cur",
#     "table_name": "dim_ant_negativos_embargos",
#     "create_table": "",
#     "associated_term": "sbi_bsf_embargos_individuos",
#     "loading_query": "WITH soj_embargos_raw AS (     SELECT         embargos.*     FROM         de_bsf_1raw.soj_embargos AS embargos     WHERE         embargos.fecha_proceso = '$FECHA_PROCESO' ), caja_ahorro AS (     SELECT         caja_de_ahorro.*     FROM         de_bsf_2cur.dim_cajas_ahorro AS caja_de_ahorro     WHERE         caja_de_ahorro.fecha_proceso = '$FECHA_PROCESO' ), cuenta_corriente AS (     SELECT         cuenta_corriente.*     FROM         de_bsf_2cur.dim_cuentas_corrientes AS cuenta_corriente     WHERE         cuenta_corriente.fecha_proceso = '$FECHA_PROCESO' ) SELECT     'Caja de Ahorro' AS fuente_registro,     CAST(raw.N_NRO_OFICIO AS BIGINT) AS id_embargo,     ca.id_cliente_core AS id_cliente_core,     ca.id_persona AS id_persona,     CAST(raw.nro_cuenta AS INT) AS nro_cta,     CAST(raw.tipo_cuenta AS INT) AS id_cta,     CAST(raw.sucursal AS INT) AS id_sucursal,     CAST(raw.N_ORIGEN AS INT) AS id_origen_embargo,     CASE         WHEN raw.N_ORIGEN = '1' THEN 'Afip y otros Organismos'         WHEN raw.N_ORIGEN = '2' THEN 'Propios'         WHEN raw.N_ORIGEN = '3' THEN 'BCRA'     END AS desc_origen_embargo,     CAST(raw.N_TIPO_EMBARGO AS INT) AS id_tipo_embargo,     CAST(raw.N_ESTADO_EMBARGO AS BIGINT) AS id_estado_embargo,     CASE         WHEN raw.N_ESTADO_EMBARGO = '1' THEN 'Bloqueo Activo'         WHEN raw.N_ESTADO_EMBARGO = '2' THEN 'Bloqueo por Monto'         WHEN raw.N_ESTADO_EMBARGO = '3' THEN 'Bloqueo por Debito'         WHEN raw.N_ESTADO_EMBARGO = '4' THEN 'Bloqueo por Haberes'         WHEN raw.N_ESTADO_EMBARGO = '5' THEN 'Bloqueo por Haberes 24h'         WHEN raw.N_ESTADO_EMBARGO = '8' THEN 'Bloqueado a Desbloquear'     END AS desc_estado,     CAST(         from_unixtime(             unix_timestamp(raw.FH_FECHA_ALTA_EMBARGO, 'MMM dd yyyy'),             'yyyy-MM-dd'         ) AS date     ) AS fecha_alta_embargo,     CAST(         from_unixtime(             unix_timestamp(raw.FH_FECHA_VENCIMIENTO, 'MMM dd yyyy'),             'yyyy-MM-dd'         ) AS date     ) AS fecha_vto_embargo,     CAST(raw.N_INTERES AS DECIMAL(15, 2)) + CAST(raw.N_CAPITAL AS DECIMAL(15, 2))  AS mto_embargo,     CAST(raw.N_MONEDA AS INT) AS id_moneda FROM     soj_embargos_raw AS RAW     INNER JOIN caja_ahorro AS ca ON CAST(raw.nro_cuenta AS INT) = ca.nro_cta     AND CAST(raw.tipo_cuenta AS INT) = ca.id_cta     AND CAST(raw.sucursal AS INT) = ca.id_sucursal UNION SELECT     'Cuenta Corriente' AS fuente_registro,     CAST(raw.N_ORIGEN AS int) AS id_embargo,     cc.id_cliente_core AS id_cliente_core,     cc.id_persona AS id_persona,     CAST(raw.nro_cuenta AS INT) AS nro_cta,     CAST(raw.tipo_cuenta AS INT) AS id_cta,     CAST(raw.sucursal AS INT) AS id_sucursal,     CAST(raw.N_ORIGEN AS INT) AS id_origen_embargo,     CASE         WHEN raw.N_ORIGEN = '1' THEN 'Afip y otros Organismos'         WHEN raw.N_ORIGEN = '2' THEN 'Propios'         WHEN raw.N_ORIGEN = '3' THEN 'BCRA'     END AS desc_origen_embargo,     CAST(raw.N_TIPO_EMBARGO AS INT) AS id_tipo_embargo,     CAST(raw.N_ESTADO_EMBARGO AS INT) AS id_estado_embargo,     CASE         WHEN raw.N_ESTADO_EMBARGO = '1' THEN 'Bloqueo Activo'         WHEN raw.N_ESTADO_EMBARGO = '2' THEN 'Bloqueo por Monto'         WHEN raw.N_ESTADO_EMBARGO = '3' THEN 'Bloqueo por Debito'         WHEN raw.N_ESTADO_EMBARGO = '4' THEN 'Bloqueo por Haberes'         WHEN raw.N_ESTADO_EMBARGO = '5' THEN 'Bloqueo por Haberes 24h'         WHEN raw.N_ESTADO_EMBARGO = '8' THEN 'Bloqueado a Desbloquear'     END AS desc_estado,     CAST(         from_unixtime(             unix_timestamp(raw.FH_FECHA_ALTA_EMBARGO, 'MMM dd yyyy'),             'yyyy-MM-dd'         ) AS date     ) AS fecha_alta_embargo,     CAST(         from_unixtime(             unix_timestamp(raw.FH_FECHA_VENCIMIENTO, 'MMM dd yyyy'),             'yyyy-MM-dd'         ) AS date     ) AS fecha_vto_embargo,     CAST(raw.N_INTERES AS DECIMAL(15, 2)) + CAST(raw.N_CAPITAL AS DECIMAL(15, 2))  AS mto_embargo,     CAST(raw.N_MONEDA AS INT) AS id_moneda FROM   ...
#     "affected_tables": [
#       "de_bsf_3ref.abt_persona_perfil_crediticio_individuos"
#     ]
#   }
# }

# %%
'''Variables'''
## Atlas dev
headers = {
    "Content-Type": "application/json",
    "Accept": "application/json"
}
credentials = HTTPBasicAuth('atlasadmin', 'xNB8lZ!Dut')
atlas_urls = ["172.30.213.141","172.30.213.142"]
atlas_port = 31000

## Hive dev
hive_host = 'edh-master-01d.root.corp'
hive_port = 10000
hive_user = 'admin'


## Impala dev
impala_host = '172.30.213.211'
impala_port = 21050
impala_user = 'admin'

# %%
#HIVE
def describe_table( hive_database, table_name ):
    #Creo la conexión y obtengo el cursos
    hive_conn = hive.connect(host=hive_host, port=hive_port, username=hive_user, database=hive_database)
    hive_cursor = hive_conn.cursor()

    # Obtengo el create
    hive_cursor.execute(f'DESCRIBE {hive_database}.{table_name}')
    databases = hive_cursor.fetchall()
    
    return databases

# %%
#IMPALA
def describe_table_impala( impala_database, table_name ):
    #Creo la conexión y obtengo el cursos
    impala_conn = connect(host=impala_host, port=impala_port, database=impala_database)
    impala_cursor = impala_conn.cursor()

    # Obtengo el create
    impala_cursor.execute(f'DESCRIBE {impala_database}.{table_name}')
    databases = impala_cursor.fetchall()
    
    return databases

# %% [markdown]
# #### Creamos el dataframe de metadata para HIVE

# %%
lista_metadata = []

for table in json_file.keys():
    if '4con' not in table and 'datamart' not in table:
        db, table_name = table.split('.')
        describe = describe_table( db, table_name )
        db_split = db.split('_')
        entidad = db_split[1]
        if 'datamart' in db:
            zona = 'datamart'
        else:
            zona = db_split[2][1:]
        
        a = list(map(lambda x: list(x)+[db, table_name, entidad, zona], describe ))
        
        lista_metadata.append(a)
# Out:
# [['id_concepto', 'tinyint', 'Código de concepto', 'de_ber_3ref', 'productos_parametria_dim_productos', 'ber', 'ref'], ['cod_producto', 'smallint', 'Código de producto', 'de_ber_3ref', 'productos_parametria_dim_productos', 'ber', 'ref'], ['id_producto', 'varchar(10)', 'Identificación del producto', 'de_ber_3ref', 'productos_parametria_dim_productos', 'ber', 'ref'], ['marca_sfb', 'char(1)', 'Señal que indica si es un producto SFB', 'de_ber_3ref', 'productos_parametria_dim_productos', 'ber', 'ref'], ['marca_producto_cta_comitente', 'char(1)', 'Señal es producto cta comitente', 'de_ber_3ref', 'productos_parametria_dim_productos', 'ber', 'ref'], ['id_moneda', 'tinyint', 'Código de moneda', 'de_ber_3ref', 'productos_parametria_dim_productos', 'ber', 'ref'], ['fecha_vencimiento_producto', 'date', 'Fecha de vencimiento del producto', 'de_ber_3ref', 'productos_parametria_dim_productos', 'ber', 'ref'], ['fecha_vigencia_producto', 'date', 'Fecha de vigencia del producto', 'de_ber_3ref', 'productos_parametria_dim_productos', 'ber', 'ref'], ['desc_producto', 'varchar(30)', 'Nombre del producto', 'de_ber_3ref', 'productos_parametria_dim_productos', 'ber', 'ref'], ['nro_campo_c_467', 'varchar(2)', 'Nro. de Campo c.467', 'de_ber_3ref', 'productos_parametria_dim_productos', 'ber', 'ref'], ['nro_campo_garantia', 'varchar(2)', 'Nro. de Campo gtia.', 'de_ber_3ref', 'productos_parametria_dim_productos', 'ber', 'ref'], ['nro_campo_lisol', 'varchar(2)', 'Nro. de Campo lisol', 'de_ber_3ref', 'productos_parametria_dim_productos', 'ber', 'ref'], ['factor_ponderacion', 'decimal(16,9)', 'Factor de ponderación ', 'de_ber_3ref', 'productos_parametria_dim_productos', 'ber', 'ref'], ['fecha_vencimiento_producto_rel', 'int', 'Fecha de vencimiento del producto en formato relativa ', 'de_ber_3ref', 'productos_parametria_dim_productos', 'ber', 'ref'], ['fecha_vigencia_producto_rel', 'int', 'Fecha de vigencia del producto en formato relativa', 'de_ber_3ref', 'productos_parametria_dim_productos', 'ber', 'ref'], ['estado', 'char(1)', 'Estado', 'de_ber_3ref', 'productos_parametria_dim_productos', 'ber', 'ref'], ['marca_producto_privado', 'char(1)', 'Señal de si Controla productos privados', 'de_ber_3ref', 'productos_parametria_dim_productos', 'ber', 'ref'], ['fecha_proceso', 'varchar(8)', '', 'de_ber_3ref', 'productos_parametria_dim_productos', 'ber', 'ref'], ['', None, None, 'de_ber_3ref', 'productos_parametria_dim_productos', 'ber', 'ref'], ['# Partition Information', None, None, 'de_ber_3ref', 'productos_parametria_dim_productos', 'ber', 'ref'], ['# col_name', 'data_type', 'comment', 'de_ber_3ref', 'productos_parametria_dim_productos', 'ber', 'ref'], ['fecha_proceso', 'varchar(8)', '', 'de_ber_3ref', 'productos_parametria_dim_productos', 'ber', 'ref']]

# %%
lista_aplanada = [item for sublist1 in lista_metadata for item in sublist1]

# %%
#HIVE
nombres_columnas = ['campo', 'tipo_dato', 'comentario', 'base','tabla','entidad','zona']

# Crear el DataFrame
df_metadata = pd.DataFrame(lista_aplanada, columns=nombres_columnas)

#Eliminamos la garbage
options = ['# Partition Information', '# col_name', ''] 
rslt_df = df_metadata.loc[~df_metadata['campo'].isin(options)]

#Guardamos
rslt_df.to_csv('data/metadata_hive.csv')

# %% [markdown]
# #### Creamos el dataframe de metadata para IMPALA <br>
# #### Agregamos un campo 'primary_key' que funciona cómo flag

# %% [markdown]
# #nombre_campo|tipo_dato|comentario|primary_key|base|tabla|entidad|zona

# %%
lista_metadata_impala = []

for table in json_file.keys():
    if '1raw' not in table and '2cur' not in table and '3ref' not in table:
        db, table_name = table.split('.')
        describe = describe_table_impala( db, table_name )
        db_split = db.split('_')
        entidad = db_split[1]
        if 'datamart' in db:
            zona = 'datamart'
        else:
            zona = db_split[2][1:]
        a = list(map(lambda x: list(x[:4])+[db, table_name, entidad, zona], describe ))
        lista_metadata_impala.append(a)

# %%
lista_aplanada_impala = [item for sublist1 in lista_metadata_impala for item in sublist1]

# %%
#IMPALA
nombres_columnas_impala = ['campo', 'tipo_dato', 'comentario','primary_key', 'base','tabla','entidad','zona']

# Crear el DataFrame
df_metadata_impala = pd.DataFrame(lista_aplanada_impala, columns=nombres_columnas_impala)

# %%
df_metadata_impala
# Out:
#                          campo      tipo_dato  \
# 0                  id_concepto        tinyint
# 1                 cod_producto       smallint
# 2                    id_moneda        tinyint
# 3                fecha_proceso     varchar(8)
# 4                  id_producto    varchar(10)
# ...                        ...            ...
# 4547               tasa_maxima   decimal(8,4)
# 4548               tasa_minima   decimal(8,4)
# 4549  mto_maximo_tasa_regulada  decimal(15,2)
# 4550           tasa_referencia   decimal(8,4)
# 4551          es_indice_moneda            int
#
#                                    comentario primary_key         base  \
# 0                          Código de concepto        true  de_ber_4con
# 1                          Código de producto        true  de_ber_4con
# 2                            Código de moneda        true  de_ber_4con
# 3     Fecha de proceso de la tabla de landing        true  de_ber_4con
# 4                 Identificación del producto       false  de_ber_4con
# ...                                       ...         ...          ...
# 4547                         Tasa Maxima p/PF       false  de_bsj_4con
# 4548                         Tasa Minima p/PF       false  de_bsj_4con
# 4549               Monto Maximo Tasa Regulada       false  de_bsj_4con
# 4550                       Tasa de Referencia       false  de_bsj_4con
# 4551             Indica si es índice o moneda       false  de_bsj_4con
#
#                                    tabla entidad zona
# 0     productos_parametria_dim_productos     ber  con
# 1     productos_parametria_dim_productos     ber  con
# 2     productos_parametria_dim_productos     ber  con
# 3     productos_parametria_dim_productos     ber  con
# 4     productos_parametria_dim_productos     ber  con
# ...                                  ...     ...  ...
# 4547    productos_parametria_dim_divisas     bsj  con
# 4548    productos_parametria_dim_divisas     bsj  con
# 4549    productos_parametria_dim_divisas     bsj  con
# 4550    productos_parametria_dim_divisas     bsj  con
# 4551    productos_parametria_dim_divisas     bsj  con
#
# [4552 rows x 8 columns]

# %%
#Guardamos
df_metadata_impala.to_csv('data/metadata_impala.csv')
